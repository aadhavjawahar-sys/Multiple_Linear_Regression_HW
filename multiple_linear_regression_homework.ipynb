# %% [markdown]
# <a href="https://colab.research.google.com/github/aadhavjawahar-sys/Multiple_Linear_Regression_HW/blob/main/multiple_linear_regression_homework.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Multiple Linear Regression Homework

# %% [markdown]
# Run the following cell to import necessary libaries and modules.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, root_mean_squared_error
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Problem 1: Multiple Linear Regression
#
# For this problem, we will run a multiple linear regression model on the iris dataset which we've worked with before.

# %% [markdown]
# First load seaborn's built in `"iris"` dataset and store it in the dataframe `df`. If you've forgotten the info that this dataset contains I encourage you to run the usual commands like `.info()` or `.head()` etc... to familiarize yourself with the dataset.

# %%
df = sns.load_dataset("iris")

# %% [markdown]
# Create and train a linear regression model which predicts the target variable `sepal_length` using the feature variable `petal_length`.  (Feel free to add more cells as needed).

# %%
X_train = df[["petal_length"]].to_numpy()
y_train = df[["sepal_length"]].to_numpy()
model = LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Now, create a multiple linear regression model using the three features: `sepal_width`, `petal_length`, and `petal_width` to predict the target variable `sepal_length`.  (Be sure to name this model something different than your first model like `model_multi` or something).

# %%
X_train2 = df[["sepal_width","petal_length","petal_width"]]
model_multi = LinearRegression()
model_multi.fit(X_train2, y_train)
# Out:
# LinearRegression()

# %%
y_predicted_linear = model.predict(X_train)
y_predicted_polynomial = model_multi.predict(X_train2)

# %% [markdown]
# Compute the MSE for both regression models.
#
# Which one is better?

# %%
#Polynomial better
print(f"MSE - linear : {mean_squared_error(y_train, y_predicted_linear)}")
print(f"MSE - poly. : {mean_squared_error(y_train, y_predicted_polynomial)}")
# Out:
# MSE - linear : 0.16350022510554504
# MSE - poly. : 0.09630269942460731

# %% [markdown]
# ### Problem 2: Polynomial Regression
#
# For this problem, I've created some simulated data.  To load the data into numpy arrays, run the following code cell. **DO NOT EDIT IT, JUST RUN IT**

# %%
### DO NOT CHANGE THIS CELL AT ALL
X = np.array([
      [-0.43639729,  6.93468622],
      [ 0.17386082,  5.38593183],
      [-2.20280755,  8.69365508],
      [-2.52078239,  9.85495551],
      [ 3.44713757,  9.10660549],
      [-4.7258837 ,  2.11790167],
      [ 1.32135298,  2.68637588],
      [ 2.71067199,  6.53198484],
      [ 1.88516508,  0.55511814],
      [ 4.79214781,  3.04878372]
    ])

Y = np.array([15.82001059, 13.08957392, 22.41546418, 31.36847782, 66.65086449,
       57.08207082, 13.51391928, 43.48950102, 14.62265983, 92.9767226])

# %% [markdown]
# The above cell created two arrays:
#
# - An $X$ array which we will think of as the feature matrix for some training data
# - A $Y$ array which we will think of as the vector of target values for the training data
#
# Notice that $X$ has 10 rows and 2 columns (so we currently have two feature variables) while $Y$ has 10 entries.  Thus, we have 10 training examples ($m=10$) and currently we have two feature variables.
#
# Let $x_0$ be the variable for the first column of $X$ and let $x_1$ be the second column.

# %% [markdown]
# In the code cell below, define NumPy arrays `X_0` and `X_1` to be the corresponding columns of $X$. Therefore,
# - `X_0` should be an array of all the $x_0$ values
# - `X_1` should be an array of all the $x_1$ values.

# %%
X_0 = X[:,0]
X_1 = X[:,1]
# Out:
# [-0.43639729  0.17386082 -2.20280755 -2.52078239  3.44713757 -4.7258837
#   1.32135298  2.71067199  1.88516508  4.79214781]

# %% [markdown]
# For this training data that I created, we will need to use $x_0$ and $x_1$ as features for our regression model.  However, there is also a quadratic (degree 2) polynomial feature that I used to create the data.  This feature is one of the following:
# $$x_0x_1, \qquad (x_0)^2, \qquad \text{or} \qquad (x_1)^2$$

# %% [markdown]
# Your task for this problem is to figure out which of these is the third feature that I used.  Do this by following these steps:
# - Create three different LinearRegression models, one for each of these quadratic features
#   - Each model should be using three features: $x_0$, $x_1$, and one of the above quadratic features.
#   - As a suggestion, I would name the three models `model1`, `model2`, and `model3` respectively.
# - For each model, compute the MSE. You may use `sklearn`'s `mean_squared_error()` function.
# - Compare the MSE for each of your three Linear Regression models to see which one is the best.
#   - This will tell you which quadratic term is actually the third feature that I used.
#
# Do this below.  Feel free to add as many code cells or text cells as you see fit to complete this task.  Try to keep your work organized and presentable.  Make sure you clearly state as your final answer which of the three quadratic features you think I used.

# %%
model1,model2,model3 = LinearRegression(),LinearRegression(),LinearRegression()
X_2,X_3,X_4 = X_0 * X_1, X_0**2, X_1**2
df = pd.DataFrame({"X_0":X_0,"X_1":X_1,"X_2":X_2,"X_3":X_3,"X_4":X_4})
X_train_1, X_train_2, X_train_3 = df.drop(columns=["X_3","X_4"]),df.drop(columns=["X_2","X_4"]),df.drop(columns=["X_2","X_3"])
model1.fit(X_train_1, Y)
model2.fit(X_train_2, Y)
model3.fit(X_train_3, Y)
y_pred_1 = model1.predict(X_train_1)
y_pred_2 = model2.predict(X_train_2)
y_pred_3 = model3.predict(X_train_3)

# %%
print(f"MSE - 1 : {mean_squared_error(Y,y_pred_1)}")
print(f"MSE - 2 : {mean_squared_error(Y,y_pred_2)}")
print(f"MSE - 3 : {mean_squared_error(Y,y_pred_3)}")

#Since MSE with model 2 has the lowest MSE, then the X_0**2 is the third term!!!
# Out:
# MSE - 1 : 518.2712729758925
# MSE - 2 : 2.9247522649906035
# MSE - 3 : 583.7216267748996
